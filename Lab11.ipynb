# %% [markdown]
# <a href="https://colab.research.google.com/github/ESMMKK/FISC-0746-estructuras-discretas-para-la-computacion/blob/master/Lab11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import defaultdict, namedtuple, Counter, deque
import csv
import random
from urllib.request import urlretrieve

# %%
pelicula_data = 'https://raw.githubusercontent.com/skielosky/FISC-0746-estructura-discretas-computacion-2019/master/laboratorios/secuencias/peliculas_metadata.csv'
pelicula_csv = 'movies.csv'
urlretrieve(pelicula_data, pelicula_csv)
# Out:
# ('movies.csv', <http.client.HTTPMessage at 0x7f3b166a36d8>)

# %%
pelicula = namedtuple('Peliculas', 'title year score')

# %%
def obtener_peliculas_por_director(data=pelicula_csv):
    """Extracts all movies from csv and stores them in a dictionary
       where keys are directors, and values is a list of movies (named tuples)"""
    directors = defaultdict(list)
    with open(data, encoding='utf-8') as f:
        for line in csv.DictReader(f):
            try:
                director = line['director_name']
                movie = line['movie_title'].replace('\xa0', '')
                year = int(line['title_year'])
                score = float(line['imdb_score'])
            except ValueError:
                continue

            m = pelicula(title=movie, year=year, score=score)
            directors[director].append(m)

    return directors

# %%
directores = obtener_peliculas_por_director()

# %%
directores
# Out:
# defaultdict(list,
#             {'James Cameron': [Peliculas(title='Avatar', year=2009, score=7.9),
#               Peliculas(title='Titanic', year=1997, score=7.7),
#               Peliculas(title='Terminator 2: Judgment Day', year=1991, score=8.5),
#               Peliculas(title='True Lies', year=1994, score=7.2),
#               Peliculas(title='The Abyss', year=1989, score=7.6),
#               Peliculas(title='Aliens', year=1986, score=8.4),
#               Peliculas(title='The Terminator', year=1984, score=8.1)],
#              'Gore Verbinski': [Peliculas(title="Pirates of the Caribbean: At World's End", year=2007, score=7.1),
#               Peliculas(title="Pirates of the Caribbean: Dead Man's Chest", year=2006, score=7.3),
#               Peliculas(title='The Lone Ranger', year=2013, score=6.5),
#               Peliculas(title='Rango', year=2011, score=7.2),
#               Peliculas(title='Pirates of the Caribbean: The Curse of the Black Pearl', year=2003, score=8.1),
# ...

# %%
## Tarea 01
1.	Por Director: Nombre, Año y Rating de la película con mejor Rating
2.	Por Director: promedio de rating
3.	Director con el mejor rating
4.	Lista de películas estrenadas en el 2016
5.	Mejor Película del 2016
6.	Director con el mejor rating en el 2016
7. Lista de peliculas que tengas dos o mas directores

# %%
may = 0.0
i= 0.0
ano = " "
pel = " "
dir = " "
for director, peliculas in directores.items():
  may=0
  for pelicula in peliculas:
    if (pelicula[2] > may):
      may = pelicula[2]
      dir = director
      pel = pelicula[0]
      ano = pelicula[1]
  print(f'La pelicula con mas rating de {dir} es {pel} en {ano} con un rating de {may}' )
# Out:
# La pelicula con mas rating de James Cameron es Terminator 2: Judgment Day en 1991 con un rating de 8.5
# La pelicula con mas rating de Gore Verbinski es Pirates of the Caribbean: The Curse of the Black Pearl en 2003 con un rating de 8.1
# La pelicula con mas rating de Sam Mendes es American Beauty en 1999 con un rating de 8.4
# La pelicula con mas rating de Christopher Nolan es The Dark Knight en 2008 con un rating de 9.0
# La pelicula con mas rating de Andrew Stanton es WALL·E en 2008 con un rating de 8.4
# La pelicula con mas rating de Sam Raimi es Evil Dead II en 1987 con un rating de 7.8
# La pelicula con mas rating de Nathan Greno es Tangled en 2010 con un rating de 7.8
# La pelicula con mas rating de Joss Whedon es The Avengers en 2012 con un rating de 8.1
# La pelicula con mas rating de David Yates es Harry Potter and the Half-Blood Prince en 2009 con un rating de 7.5
# La pelicula con mas rating de Zack Snyder es Watchmen en 2009 con un rating de 7.7
# ...

# %%
mas = 0
dir = " "
for director, peliculas in directores.items():
  sum = 0
  for pelicula in peliculas:
    sum = sum + pelicula[2]
    prom = sum/len(peliculas)
  print(f'{director} tiene un rating promedio de {prom:.2f}' )
# Out:
# James Cameron tiene un rating promedio de 7.91
# Gore Verbinski tiene un rating promedio de 6.99
# Sam Mendes tiene un rating promedio de 7.50
# Christopher Nolan tiene un rating promedio de 8.43
# Andrew Stanton tiene un rating promedio de 7.73
# Sam Raimi tiene un rating promedio de 6.91
# Nathan Greno tiene un rating promedio de 7.80
# Joss Whedon tiene un rating promedio de 7.92
# David Yates tiene un rating promedio de 7.05
# Zack Snyder tiene un rating promedio de 7.17
# Bryan Singer tiene un rating promedio de 7.29
# Marc Forster tiene un rating promedio de 7.15
# Andrew Adamson tiene un rating promedio de 7.08
# Rob Marshall tiene un rating promedio de 6.60
# Barry Sonnenfeld tiene un rating promedio de 6.46
# Peter Jackson tiene un rating promedio de 7.68
# Marc Webb tiene un rating promedio de 7.13
# Ridley Scott tiene un rating promedio de 7.07
# Chris Weitz tiene un rating promedio de 6.08
# Anthony Russo tiene un rating promedio de 7.00
# ...

# %%
mas = 0
dir = " "
for director, peliculas in directores.items():
  sum = 0
  for pelicula in peliculas:
    sum = sum + pelicula[2]
    prom = sum/len(peliculas)
    if (prom>mas):
      mas = pelicula[2]
      dir = director
print(f'EL director {dir} tiene el mejor rating con {mas:.2f}' )
# Out:
# EL director Mitchell Altieri tiene el mejor rating con 8.70

# %%
may = 0.0
i= 0.0
ano = " "
pel = " "
dir = " "
print("Las peliculas estrenadas en 2016 fueron \n")
for director, peliculas in directores.items():
  for pelicula in peliculas:  
    if (pelicula[1] == 2016):
      print(f'{pelicula[0]}' )
# Out:
# Las peliculas estrenadas en 2016 fueron
#
# The Legend of Tarzan
# The Legend of Tarzan
# Batman v Superman: Dawn of Justice
# X-Men: Apocalypse
# Captain America: Civil War
# 13 Hours
# The Conjuring 2
# The BFG
# Star Trek Beyond
# Independence Day: Resurgence
# The Jungle Book
# The Jungle Book
# Suicide Squad
# Risen
# Godzilla Resurgence
# Godzilla Resurgence
# Alice Through the Looking Glass
# Warcraft
# Ghostbusters
# Ghostbusters
# Kung Fu Panda 3
# Gods of Egypt
# Now You See Me 2
# Jason Bourne
# Allegiant
# Ride Along 2
# The Huntsman: Winter's War
# Teenage Mutant Ninja Turtles: Out of the Shadows
# I Am Wrath
# Zoolander 2
# Ben-Hur
# Ben-Hur
# Ben-Hur
# Free State of Jones
# Race
# The Secret Life of Pets
# The Angry Birds Movie
# The Finest Hours
# London Has Fallen
# Xi you ji zhi: Sun Wukong san da Baigu Jing
# Deadpool
# Central Intelligence
# The Shallows
# Kickboxer: Vengeance
# Florence Foster Jenkins
# The Infiltrator
# Pride and Prejudice and Zombies
# ...

# %%
may = 0.0
i= 0.0
ano = " "
pel = " "
dir = " "

for director, peliculas in directores.items():
  for pelicula in peliculas:  
    if (pelicula[1] == 2016):
      if (pelicula[2] > may):
        may = pelicula[2]
        pel = pelicula[0]
print (f'La mejor pelicula de 2016 fue {pel} con un rating de {may}')
# Out:
# La mejor pelicula de 2016 fue Kickboxer: Vengeance con un rating de 9.1

# %%
may = 0.0
i= 0.0
ano = " "
pel = " "
dir = " "

for director, peliculas in directores.items():
  for pelicula in peliculas:  
    if (pelicula[1] == 2016):
      if (pelicula[2] > may):
        may = pelicula[2]
        dir = director
print (f'El driector con la pelicula de mas rating de 2016 fue {dir} con un rating de {may}')
# Out:
# El driector con la pelicula de mas rating de 2016 fue John Stockwell con un rating de 9.1
