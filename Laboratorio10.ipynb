# %% [markdown]
# <a href="https://colab.research.google.com/github/ESMMKK/FISC-0746-estructuras-discretas-para-la-computacion/blob/master/Laboratorio10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import defaultdict, namedtuple, Counter, deque
import csv
import random
from urllib.request import urlretrieve

# %%
pelicula_data = 'https://raw.githubusercontent.com/pybites/challenges/solutions/13/movie_metadata.csv'
pelicula_csv = 'movies.csv'
urlretrieve(pelicula_data, pelicula_csv)
# Out:
# ('movies.csv', <http.client.HTTPMessage at 0x7fc8fe65a748>)

# %%
pelicula = namedtuple('Peliculas', 'title year score')

# %%
def obtener_peliculas_por_director(data=pelicula_csv):
    """Extracts all movies from csv and stores them in a dictionary
       where keys are directors, and values is a list of movies (named tuples)"""
    directors = defaultdict(list)
    with open(data, encoding='utf-8') as f:
        for line in csv.DictReader(f):
            try:
                director = line['director_name']
                movie = line['movie_title'].replace('\xa0', '')
                year = int(line['title_year'])
                score = float(line['imdb_score'])
            except ValueError:
                continue

            m = pelicula(title=movie, year=year, score=score)
            directors[director].append(m)

    return directors

# %%
director = obtener_peliculas_por_director()

# %%
director

# %%
ContadordeDirectores=0
ContadordePeliculas=0
for directores, peliculas in director.items():
  #print(directores)
  ContadordeDirectores+=len(directores)
  ContadordePeliculas+=len(peliculas)
  print(f'El director {directores} tiene { len(peliculas)} peliculas.')
print(f'Total de directores es: { len(directores)}')
print(f'Total de Peliculas es: { ContadordePeliculas}')

#mayor=0
#for directores, peliculas in director.items():
#  for score in director.items():
  #  if(score>mayor):
  #    mayor=score
#print(f'Director {directores} Mantiene su mejor SCORE es de: {mayor:.2f}')
# Out:
# El director James Cameron tiene 7 peliculas.
# El director Gore Verbinski tiene 7 peliculas.
# El director Sam Mendes tiene 8 peliculas.
# El director Christopher Nolan tiene 8 peliculas.
# El director Andrew Stanton tiene 3 peliculas.
# El director Sam Raimi tiene 13 peliculas.
# El director Nathan Greno tiene 1 peliculas.
# El director Joss Whedon tiene 4 peliculas.
# El director David Yates tiene 4 peliculas.
# El director Zack Snyder tiene 8 peliculas.
# El director Bryan Singer tiene 8 peliculas.
# El director Marc Forster tiene 8 peliculas.
# El director Andrew Adamson tiene 5 peliculas.
# El director Rob Marshall tiene 5 peliculas.
# El director Barry Sonnenfeld tiene 7 peliculas.
# El director Peter Jackson tiene 12 peliculas.
# El director Marc Webb tiene 3 peliculas.
# El director Ridley Scott tiene 17 peliculas.
# El director Chris Weitz tiene 5 peliculas.
# El director Anthony Russo tiene 4 peliculas.
# El director Peter Berg tiene 6 peliculas.
# ...
